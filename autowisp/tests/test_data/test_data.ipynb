# %% [markdown]
# <a name="top"></a>
# # AutoWISP
# [![AutoWISP](https://github.com/kpenev/AutoWISP/blob/master/AutoWISP.png)](https://github.com/kpenev/AutoWISP)
# [![language](https://img.shields.io/badge/Python-3776AB?logo=python&logoColor=fff)](https://www.python.org/about/)
# [![OS](https://img.shields.io/badge/OS-linux%2C%20windows%2C%20macOS-0078D4)](https://github.com/kpenev/AutoWISP/tree/master/documentation)
# [![CPU](https://img.shields.io/badge/CPU-x86%2C%20x64%2C%20ARM%2C%20ARM64-FF8C00)](https://github.com/kpenev/AutoWISP/tree/master/documentation)
# [![GitHub release](https://img.shields.io/github/v/release/kpenev/AutoWISP)](#)
# [![GitHub release date](https://img.shields.io/github/release-date/kpenev/AutoWISP)](#)
# [![GitHub last commit](https://img.shields.io/github/last-commit/kpenev/AutoWISP)](#)
# [![getting started](https://img.shields.io/badge/getting_started-guide-1D76DB)](https://github.com/kpenev/AutoWISP/tree/master/documentation)
# [![Free](https://img.shields.io/badge/free_for_non_commercial_use-brightgreen)](#-license)
#
# ⭐ Star us on GitHub — it motivates us a lot!
#
# ## Table of Contents
# - [About](#-about)
# - [How to Install](#-how-to-install)
# - [Documentation](#-documentation)
# - [Feedback and Contributions](#-feedback-and-contributions)
# - [License](#-license)
# - [Contacts](#%EF%B8%8F-contacts)
#
# ## 🚀 About
#
# **AutoWISP** is a Python package designed to allow users to automatically create and de-trend light curves from their astronomical data. It adheres to high standards of flexibility, reusability, and reliability, utilizing well-known software design patterns, including modular and hexagonal architectures. These patterns ensure the following benefits:
#
# - **Modularity**: Different parts of the package can function independently, enhancing the package's modularity and allowing for easier maintenance and updates.
# - **Testability**: Improved separation of concerns makes the code more testable.
# - **Maintainability**: Clear structure and separation facilitate better management of the codebase.
#
# ## 📝 How to Install
#
# To build the packages, follow these steps:
#
# Use the package manager [pip](https://pip.pypa.io/en/stable/) to install AutoWISP.
#
#     pip install autowisp
#
# ## 📚 Documentation
#
# ### Getting Started
# Explore the [Getting Started Guide](https://github.com/kpenev/AutoWISP/tree/master/documentation).
# In this guide, you will go step by step in the pipeline, producing the corresponding files needed for each step and ultimately creating light curves.
#
# ** See below for usage of each step, included is a configuration file to perform the tests.
#
# To better understand the AutoWISP pipeline, we recommend visiting our [Documentation](https://github.com/kpenev/AutoWISP/tree/master/documentation) site.
# There, you will find useful information about the individual steps, database, and/or browser-user-interface (currently under development).
#
# ## 🤝 Feedback and Contributions
#
# We've made every effort to implement all the main aspects of AutoWISP in the best possible way. However, the development journey doesn't end here, and your input is crucial for our continuous integration and development.
#
# > [!IMPORTANT]
# > Whether you have feedback on features, have encountered any bugs, or have suggestions for enhancements, we're eager to hear from you. Your insights help us make the AutoWISP package more robust and user-friendly.
#
# Please feel free to contribute by [submitting an issue](https://github.com/kpenev/AutoWISP/issues) or [joining the discussions](https://github.com/kpenev/AutoWISP/discussions). Each contribution helps us grow and improve.
#
# We appreciate your support and look forward to making our pipeline even better with your help!
#
# ## 📃 License
#
# This package is distributed under the MIT License. You can review the full license agreement at the following link: [MIT](https://choosealicense.com/licenses/mit/).
#
# For non-commercial use, this product is available for free.
#
# ## 🗨️ Contacts
#
# For more details about our usages, services, or any general information regarding the AutoWISP pipeline, feel free to reach out to us. We are here to provide support and answer any questions you may have. Below are the best ways to contact our team:
#
# - **Email**: Send us your inquiries or support requests at [support_autowisp@gmail.com](mailto:support_autowisp@gmail.com).
#
# We look forward to assisting you and ensuring your experience with AutoWISP is successful and enjoyable!
#
# [Back to top](#top)

# %% [markdown]
# ## Testing
# The following will walk you through processing a very small collection of images to lightcurves.

# %% [markdown]
# ### Create a temporary directory to work in (will be deleted at the end), enter it, and get its path

# %%
# %mkdir autowisp_test
# %cd autowisp_test
# Out:
# mkdir: autowisp_test: File exists
# /Users/kpenev/projects/git/AutoWISP/autowisp/tests/test_data/autowisp_test

# %% [markdown]
# ### Download the test data
#
# The raw images processed in this example as well as the expected files that processing will produce can be downloaded from:
# (https://zenodo.org/records/15786531/files/test_data.zip?download=1)
#
# Download the zip file from zenodo and unpack it. This will produce several directories called: `CAL`, `DR`, `Gaia`, `LC`, `MASTERS`, and `RAW`. It should also produce several files, one of which is called `test.cfg`.
#
# Move `RAW` and `test.cfg` to the directory we just created.
#
# The remaining directories contain the files that processing should produce. You can compare what you get to those files.

# %% [markdown]
# ### Perform the calibration for the zero frames

# %%
# !wisp-calibrate --config-file test.cfg RAW/zero

# %% [markdown]
# This should produce a directory called `CAL` under which there will be another directory called `zero` which contains the calibrated bias frames.

# %% [markdown]
# ### Create a master bias by stacking the calibrated zero frames

# %%
# !wisp-stack-to-master -c test.cfg CAL/zero/

# %% [markdown]
# This should produce a directory called MASTERS containing a single FITS file, which is the master bias.

# %% [markdown]
# ### Perform the calibration for the dark frames
#
# Note that when calibrating the dark frames we wish to subtract the master bias generated above. In order to do this, we specify that the master that was generated above should be used as a master bias by adding `--master-bias "R:MASTERS/zero_R.fits.fz"` to our command line

# %%
# !wisp-calibrate --config-file test.cfg RAW/dark/*.fits.fz --master-bias "R:MASTERS/zero_R.fits.fz"

# %% [markdown]
# There should now be another directory under `CAL`, called `dark` which contains the calibrated dark frames.

# %% [markdown]
# ### Create a master dark by stacking the calibrated dark images

# %%
# !wisp-stack-to-master -c test.cfg CAL/dark/

# %% [markdown]
# ### Perform calibration for flat frames
# Those should be corrected both with the master bias and the master dark generated in the previous two steps:

# %%
# !wisp-calibrate --config-file test.cfg RAW/flat/*.fits.fz --master-bias "R:MASTERS/zero_R.fits.fz" --master-dark "R:MASTERS/dark_R.fits.fz"

# %% [markdown]
# ### Build a master flat out of the individual calibrated flat frames
#
# Note that creating a master flat uses a different command than creating master bias and dark!

# %%
# !wisp-stack-to-master-flat -c test.cfg CAL/flat/

# %% [markdown]
# ### Perform calibration for object frames
# Now we use all three masters

# %%
# !wisp-calibrate --config-file test.cfg RAW/object/*.fits.fz --master-bias "R:MASTERS/zero_R.fits.fz" --master-dark "R:MASTERS/dark_R.fits.fz" --master-flat "R:MASTERS/flat_R.fits.fz"

# %% [markdown]
# ### Find stars in the calibrated object frames
# This will create another directory called `DR` which contains what we call data reduction files. These files are where the pipeline saves  the results of processing the calibrated images. So fare, these files will only contain the stars that we find in the images.

# %%
# !wisp-find-stars --config-file test.cfg CAL/object/
# Out:
# 2025-07-03 10:40:15,077 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,080 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,081 INFO sqlalchemy.engine.Engine [generated in 0.00036s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,088 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,089 INFO sqlalchemy.engine.Engine [generated in 0.00077s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,092 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,092 INFO sqlalchemy.engine.Engine [generated in 0.00032s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,095 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,096 INFO sqlalchemy.engine.Engine [generated in 0.00030s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,097 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,099 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,102 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,102 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,108 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,108 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,111 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,111 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,115 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,115 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,116 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,154 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,161 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,161 INFO sqlalchemy.engine.Engine [generated in 0.00031s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,169 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,170 INFO sqlalchemy.engine.Engine [generated in 0.00033s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,173 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,173 INFO sqlalchemy.engine.Engine [generated in 0.00034s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,177 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,180 INFO sqlalchemy.engine.Engine [generated in 0.00285s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,181 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,222 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,226 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,226 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,233 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,234 INFO sqlalchemy.engine.Engine [generated in 0.00044s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,234 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,237 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,238 INFO sqlalchemy.engine.Engine [generated in 0.00195s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,238 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,245 INFO sqlalchemy.engine.Engine [generated in 0.00697s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,242 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,253 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,255 INFO sqlalchemy.engine.Engine [generated in 0.00216s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,255 INFO sqlalchemy.engine.Engine [generated in 0.01257s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,256 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,257 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,258 INFO sqlalchemy.engine.Engine [generated in 0.00054s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,261 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,262 INFO sqlalchemy.engine.Engine [generated in 0.00031s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,263 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,396 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,398 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,400 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,400 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,402 INFO sqlalchemy.engine.Engine [generated in 0.00194s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,405 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,405 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,408 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:15,409 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,410 INFO sqlalchemy.engine.Engine [generated in 0.00137s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,411 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,410 INFO sqlalchemy.engine.2025-07-03 10:40:15,411 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('data_reduction', 1, 0)
# Engine BEGIN (implicit)
# 2025-07-03 10:40:15,411 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,411 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,412 INFO sqlalchemy.engine.Engine [generated in 0.00034s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,412 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,413 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,414 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,414 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,414 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,415 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:40:15,415 INFO sqlalchemy.engine.Engine [generated in 0.00030s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,417 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,417 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,417 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,418 INFO sqlalchemy.engine.Engine [generated in 0.00040s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,418 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,418 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,418 INFO sqlalchemy.engine.Engine [generated in 0.00046s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,419 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,419 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,419 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,420 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,421 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,421 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,422 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,423 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:15,423 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,424 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,424 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,424 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,424 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,425 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,425 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:15,425 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,425 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:15,428 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:15,428 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 1, 0)
# 2025-07-03 10:40:15,429 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Perform astrometry on DR files
# This matches the extracted sources to a catalog of stars from the Gaia space mission and uses that information to figure out how to convert from coordinates on the sky to coordinates within each image. The conversion will also be stored in the DR files.
#
# Note that this may take a while, since we use an online service to find an initial guess which is often over-subscribed.

# %%
# !wisp-solve-astrometry --config-file test.cfg DR/
# Out:
# 2025-07-03 10:40:19,060 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:19,062 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:19,062 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:40:19,066 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:19,066 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 0)
# 2025-07-03 10:40:19,067 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:19,067 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:40:19,069 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:19,069 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('data_reduction', 0)
# 2025-07-03 10:40:19,070 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,375 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,378 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,378 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# 2025-07-03 10:40:24,384 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,384 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:40:24,386 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,387 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('data_reduction', 0)
# 2025-07-03 10:40:24,390 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,390 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:40:24,391 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,450 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,453 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,453 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:40:24,458 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,458 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:40:24,460 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,460 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('data_reduction', 0)
# 2025-07-03 10:40:24,463 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,463 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('data_reduction', 0)
# 2025-07-03 10:40:24,464 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,562 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,565 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,565 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:40:24,571 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,571 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:40:24,571 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,573 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,573 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('data_reduction', 0)
# 2025-07-03 10:40:24,574 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,574 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:40:24,576 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,576 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:40:24,577 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,579 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,580 INFO sqlalchemy.engine.Engine [generated in 0.00017s] ('data_reduction', 0)
# 2025-07-03 10:40:24,581 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,582 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:40:24,584 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,584 INFO sqlalchemy.engine.Engine [generated in 0.00017s] ('data_reduction', 0)
# 2025-07-03 10:40:24,585 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,762 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,765 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,765 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:40:24,770 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,770 INFO sqlalchemy.engine.Engine [generated in 0.00017s] ('data_reduction', 0)
# 2025-07-03 10:40:24,772 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,772 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:40:24,775 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,775 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:40:24,776 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,792 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,795 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,795 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:40:24,800 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,800 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('data_reduction', 0)
# 2025-07-03 10:40:24,802 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,802 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:40:24,805 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,805 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:40:24,806 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,815 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,818 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,818 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:40:24,820 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,821 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,823 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,823 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('data_reduction', 0)
# 2025-07-03 10:40:24,823 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,823 INFO sqlalchemy.engine.Engine [generated in 0.00017s] ('data_reduction', 0)
# 2025-07-03 10:40:24,824 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,824 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:40:24,825 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,825 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:40:24,828 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,828 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:40:24,828 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,828 INFO sqlalchemy.engine.Engine [generated in 0.00016s] ('data_reduction', 0)
# 2025-07-03 10:40:24,829 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,829 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,829 INFO sqlalchemy.engine.Engine [generated in 0.00016s] ('data_reduction', 0)
# 2025-07-03 10:40:24,830 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,830 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:40:24,831 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,831 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:40:24,833 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,833 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:40:24,834 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,834 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,834 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:40:24,835 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:40:24,845 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:40:24,848 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:40:24,848 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('data_reduction', 0)
# 2025-07-03 10:40:24,852 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:40:24,852 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:40:24,854 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:40:24,854 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:40:24,856 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:40:24,857 INFO sqlalchemy.engine.Engine [generated in 0.00016s] ('data_reduction', 0)
# 2025-07-03 10:40:24,857 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Perform PSF/PRF fitting

# %%
# !wisp-fit-star-shape --config test.cfg CAL/object/
# Out:
# 2025-07-03 10:43:12,531 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:12,533 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:12,533 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:43:12,537 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:12,537 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:43:12,539 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:12,539 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:43:12,541 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:12,541 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 0)
# 2025-07-03 10:43:12,541 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:19,096 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,096 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,098 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,099 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,099 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:19,099 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,099 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,099 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,100 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:19,100 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,100 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('data_reduction', 0)
# 2025-07-03 10:43:19,101 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,101 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,101 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:43:19,102 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,102 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:19,103 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,103 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('data_reduction', 0)
# 2025-07-03 10:43:19,104 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,104 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('data_reduction', 0)
# 2025-07-03 10:43:19,104 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,106 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,106 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:19,107 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,107 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:19,107 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,107 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('data_reduction', 0)
# 2025-07-03 10:43:19,107 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,107 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_p2025-07-03 10:43:19,107 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# roduct_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,108 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:19,108 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ('data_reduction', 0)
# 2025-07-03 10:43:19,108 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:19,108 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('data_reduction', 0)
# 2025-07-03 10:43:19,109 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:19,109 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('data_reduction', 0)
# 2025-07-03 10:43:19,110 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,110 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_ver2025-07-03 10:43:19,110 INFO sqlalchemy.engine.Engine [generated in 0.00048s] ('data_reduction', 0)
# 2025-07-03 10:43:19,110 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# sions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:19,110 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,110 INFO sqlalchemy.engine.Engine [generated in 0.00050s] ('data_reduction', 0)
# 2025-07-03 10:43:19,111 INFO sqlalchemy.engine.Engine [generated in 0.00046s] ('data_reduction', 0)
# 2025-07-03 10:43:19,110 INFO sqlalchemy.engine.Engine [generated in 0.00046s] ('data_reduction', 0)
# 2025-07-03 10:43:19,111 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,111 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:19,111 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:19,111 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# 2025-07-03 10:43:19,112 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:19,112 INFO sqlalchemy.engine.Engine [generated in 0.00031s] ('data_reduction', 0)
# 2025-07-03 10:43:19,113 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_2025-07-03 10:43:19,113 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:19,113 INFO sqlalchemy.engine.Engine [generated in 0.00036s] ('data_reduction', 0)
# 2025-07-03 10:43:19,113 INFO sqlalchemy.engine.Engine [generated in 0.00045s] ('data_reduction', 0)
# 2025-07-03 10:43:19,113 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:19,114 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:19,114 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attr2025-07-03 10:43:19,114 INFO sqlalchemy.engine.Engine [generated in 0.00048s] ('data_reduction', 0)
# 2025-07-03 10:43:19,114 INFO sqlalchemy.engine.Engine COMMIT
# ibutes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:19,114 INFO sqlalchemy.engine.Engine [generated in 0.00055s] ('data_reduction', 0)
# 2025-07-03 10:43:19,114 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id2025-07-03 10:43:19,115 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
#  AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:19,115 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,115 INFO sqlalchemy.engine.Engine [generated in 0.00054s] ('data_reduction', 0)
# 2025-07-03 10:43:19,115 INFO sqlalchemy.engine.Engine [generated in 0.00093s] ('data_reduction', 0)
# 2025-07-03 10:43:19,116 INFO sqlalchemy.engine.Engine [generated in 0.00074s] ('data_reduction', 0)
# 2025-07-03 10:43:19,117 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:19,117 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:19,117 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:19,118 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:19,118 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM2025-07-03 10:43:19,118 INFO sqlalchemy.engine.Engine [generated in 0.00089s] ('data_reduction', 0)
# 2025-07-03 10:43:19,118 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
#  hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:19,118 INFO sqlalchemy.engine.Engine [generated in 0.00046s] ('data_reduction', 0)
# 2025-07-03 10:43:19,118 INFO sqlalchemy.engine.Engine [generated in 0.00048s] ('data_reduction', 0)
# 2025-07-03 10:43:19,118 INFO sqlalchemy.engine.Engine [generated in 0.00047s] ('data_reduction', 0)
# 2025-07-03 10:43:19,118 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:19,119 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:19,119 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:19,119 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:19,119 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('data_reduction', 0)
# 2025-07-03 10:43:19,121 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:19,123 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:19,123 INFO sqlalchemy.engine.Engine [generated in 0.00053s] ('data_reduction', 0)
# 2025-07-03 10:43:19,124 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:19,123 INFO sqlalchemy.engine.Engine [generated in 0.00240s] ('data_reduction', 0)
# 2025-07-03 10:43:19,133 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:19,134 INFO sqlalchemy.engine.Engine [generated in 0.00063s] ('data_reduction', 0)
# 2025-07-03 10:43:19,135 INFO sqlalchemy.engine.Engine COMMIT
# Reading model
# Reading grid
# Reading coefficients
# Reading model
# Reading grid
# Reading coefficients
# Reading model
# Reading grid
# Reading coefficients
# Reading model
# Reading grid
# Reading coefficients
# Reading model
# Reading grid
# Reading coefficients
# Reading model
# Reading grid
# Reading coefficients
# Reading model
# Reading grid
# Reading coefficients
# Reading model
# Reading grid
# Reading coefficients
# Reading model
# Reading grid
# Reading coefficients

# %% [markdown]
# ### Perform aperture photometry

# %%
# !wisp-measure-aperture-photometry --config test.cfg CAL/object/
# Out:
# 2025-07-03 10:43:25,851 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:25,853 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:25,853 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:43:25,856 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:25,856 INFO sqlalchemy.engine.Engine [generated in 0.00010s] ('data_reduction', 0)
# 2025-07-03 10:43:25,858 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:25,858 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:43:25,860 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:25,860 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 0)
# 2025-07-03 10:43:25,860 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:30,243 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,246 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,246 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:30,252 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,252 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:30,254 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,255 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('data_reduction', 0)
# 2025-07-03 10:43:30,258 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,258 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:43:30,259 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:30,343 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,346 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,349 INFO sqlalchemy.engine.Engine [generated in 0.00338s] ('data_reduction', 0)
# 2025-07-03 10:43:30,356 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,356 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:30,358 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,358 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:43:30,361 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,361 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# 2025-07-03 10:43:30,362 INFO sqlalchemy.engine.Engine COMMIT
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Reading background
# 2025-07-03 10:43:30,445 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,448 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,451 INFO sqlalchemy.engine.Engine [generated in 0.00319s] ('data_reduction', 0)
# 2025-07-03 10:43:30,458 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,458 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:30,458 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,458 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,459 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,459 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,460 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,460 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:30,461 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,461 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:30,461 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,461 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:30,462 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,462 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:30,462 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,462 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:30,463 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,463 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# 2025-07-03 10:43:30,464 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:30,467 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,467 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:30,467 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,467 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:43:30,468 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,468 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:43:30,468 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,469 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:30,469 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,470 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:30,470 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,470 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:43:30,470 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,470 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:43:30,471 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,471 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:43:30,472 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,472 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,472 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,473 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:43:30,473 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:30,473 INFO sqlalchemy.engine.Engine [generated in 0.00033s] ('data_reduction', 0)
# 2025-07-03 10:43:30,473 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:30,473 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,474 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:30,474 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('data_reduction', 0)
# 2025-07-03 10:43:30,474 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,474 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# 2025-07-03 10:43:30,474 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:30,475 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:30,475 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,475 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:43:30,476 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:30,476 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:30,481 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,482 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:30,482 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:30,482 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:43:30,484 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,484 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('data_reduction', 0)
# 2025-07-03 10:43:30,484 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:30,484 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:30,487 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,487 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('data_reduction', 0)
# 2025-07-03 10:43:30,488 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:30,488 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('data_reduction', 0)
# 2025-07-03 10:43:30,488 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:30,489 INFO sqlalchemy.engine.Engine COMMIT
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Reading background
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Reading background
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Reading background
# Reading background
# Reading background
# Reading background
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Setting apertures
# Reading PSF map
# Reading model
# Reading grid
# Reading coefficients
# Creating flux measuring object
# Measuring flux for image 0
# tree suffix = .0
# Reading background
# Reading background

# %% [markdown]
# ### Run fit source extracted PSF map

# %%
# !wisp-fit-source-extracted-psf-map --config test.cfg DR/
# Out:
# 2025-07-03 10:43:34,206 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:34,208 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:34,208 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:43:34,212 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:34,212 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 0)
# 2025-07-03 10:43:34,213 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:34,213 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('data_reduction', 0)
# 2025-07-03 10:43:34,215 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:34,216 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:43:34,216 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Perform magnitude fitting

# %%
# !wisp-fit-magnitudes --config test.cfg DR/
# Out:
# 2025-07-03 10:43:37,719 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:37,721 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:37,721 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:43:37,725 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:37,725 INFO sqlalchemy.engine.Engine [generated in 0.00010s] ('data_reduction', 0)
# 2025-07-03 10:43:37,726 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:37,726 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('data_reduction', 0)
# 2025-07-03 10:43:37,728 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:37,729 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('data_reduction', 0)
# 2025-07-03 10:43:37,729 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:43,312 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:43,315 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:43,315 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:43:43,321 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:43,321 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:43,323 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:43,324 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('data_reduction', 0)
# 2025-07-03 10:43:43,327 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:43,328 INFO sqlalchemy.engine.Engine [generated in 0.00031s] ('data_reduction', 0)
# 2025-07-03 10:43:43,328 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:43,372 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:43,375 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:43,375 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:43,381 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:43,381 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:43:43,383 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:43,383 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('data_reduction', 0)
# 2025-07-03 10:43:43,387 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:43,388 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# 2025-07-03 10:43:43,389 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:43,390 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:43,393 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:43,393 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:43,400 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:43,400 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:43:43,403 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:43,403 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:43:43,406 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:43,406 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# 2025-07-03 10:43:43,407 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:43,446 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:43,450 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:43,450 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('data_reduction', 0)
# 2025-07-03 10:43:43,457 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:43,457 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:43,460 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:43,460 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ('data_reduction', 0)
# 2025-07-03 10:43:43,464 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:43,464 INFO sqlalchemy.engine.Engine [generated in 0.00057s] ('data_reduction', 0)
# 2025-07-03 10:43:43,465 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:43,546 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:43,549 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:43,549 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:43,565 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:43,565 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:43,570 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:43,573 INFO sqlalchemy.engine.Engine [generated in 0.00284s] ('data_reduction', 0)
# 2025-07-03 10:43:43,576 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:43,585 INFO sqlalchemy.engine.Engine [generated in 0.00911s] ('data_reduction', 0)
# 2025-07-03 10:43:43,587 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:43,594 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:43,598 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:43,598 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('data_reduction', 0)
# 2025-07-03 10:43:43,604 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:43,604 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('data_reduction', 0)
# 2025-07-03 10:43:43,606 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:43,606 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('data_reduction', 0)
# 2025-07-03 10:43:43,609 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:43,609 INFO sqlalchemy.engine.Engine [generated in 0.00031s] ('data_reduction', 0)
# 2025-07-03 10:43:43,610 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:50,034 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:50,037 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:50,037 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:43:50,042 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:50,042 INFO sqlalchemy.engine.Engine [generated in 0.00017s] ('data_reduction', 0)
# 2025-07-03 10:43:50,044 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:50,044 INFO sqlalchemy.engine.Engine [generated in 0.00030s] ('data_reduction', 0)
# 2025-07-03 10:43:50,048 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:50,048 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ('data_reduction', 0)
# 2025-07-03 10:43:50,049 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:50,155 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:50,158 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:50,158 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:43:50,165 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:50,165 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('data_reduction', 0)
# 2025-07-03 10:43:50,166 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:50,171 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:50,171 INFO sqlalchemy.engine.Engine [generated in 0.00043s] ('data_reduction', 0)
# 2025-07-03 10:43:50,171 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:50,171 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('data_reduction', 0)
# 2025-07-03 10:43:50,175 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:50,175 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('data_reduction', 0)
# 2025-07-03 10:43:50,176 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:50,180 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:43:50,180 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('data_reduction', 0)
# 2025-07-03 10:43:50,195 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:50,204 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:43:50,204 INFO sqlalchemy.engine.Engine [generated in 0.00043s] ('data_reduction', 0)
# 2025-07-03 10:43:50,204 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:43:50,206 INFO sqlalchemy.engine.Engine [generated in 0.00188s] ('data_reduction', 0)
# 2025-07-03 10:43:50,212 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_2025-07-03 10:43:50,212 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:43:50,218 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:43:50,224 INFO sqlalchemy.engine.Engine [generated in 0.01179s] ('data_reduction', 0)
# 2025-07-03 10:43:50,224 INFO sqlalchemy.engine.Engine [generated in 0.01225s] ('data_reduction', 0)
# 2025-07-03 10:43:50,225 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:43:50,227 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# ...
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_2025-07-03 10:44:16,722 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:16,734 INFO sqlalchemy.engine.Engine [generated in 0.01245s] ('data_reduction', 0)
# versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:16,735 INFO sqlalchemy.engine.Engine [generated in 0.01747s] ('data_reduction', 0)
# 2025-07-03 10:44:16,735 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:16,736 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:16,863 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:16,863 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:16,866 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:16,866 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:44:16,867 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:16,872 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (S2025-07-03 10:44:16,872 INFO sqlalchemy.engine.Engine [generated in 0.00574s] ('data_reduction', 0)
# ELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:16,873 INFO sqlalchemy.engine.Engine [generated in 0.00072s] ('data_reduction', 0)
# 2025-07-03 10:44:16,875 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:16,876 INFO sqlalchemy.engine.Engine [generated in 0.00031s] ('data_reduction', 0)
# 2025-07-03 10:44:16,879 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:16,879 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:44:16,880 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:16,880 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:16,880 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:44:16,882 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:16,883 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:44:16,886 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:16,886 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('data_reduction', 0)
# 2025-07-03 10:44:16,887 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:16,892 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:16,895 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:16,895 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:44:16,901 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:16,901 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('data_reduction', 0)
# 2025-07-03 10:44:16,903 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:16,903 INFO sqlalchemy.engine.Engine [generated in 0.00036s] ('data_reduction', 0)
# 2025-07-03 10:44:16,907 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:16,907 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('data_reduction', 0)
# 2025-07-03 10:44:16,908 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Create light curves

# %%
# !wisp-create-lightcurves --config test.cfg DR/
# Out:
# 2025-07-03 10:44:21,419 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:21,421 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:21,421 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:44:21,424 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:21,424 INFO sqlalchemy.engine.Engine [generated in 0.00010s] ('data_reduction', 0)
# 2025-07-03 10:44:21,426 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:21,426 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:44:21,428 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:21,428 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:44:21,428 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:21,850 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:21,851 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:44:21,851 INFO sqlalchemy.engine.Engine [generated in 0.00009s] ('light_curve', 1, 0)
# 2025-07-03 10:44:21,854 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:21,854 INFO sqlalchemy.engine.Engine [generated in 0.00009s] ('light_curve', 1, 0)
# 2025-07-03 10:44:21,855 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:21,855 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('light_curve', 1, 0)
# 2025-07-03 10:44:21,856 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:21,856 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('light_curve', 1, 0)
# 2025-07-03 10:44:21,857 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Perform EPD on light curves

# %%
# !wisp-epd --config test.cfg LC/
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 2
# Parsing: 'sphotref = apphot.magfit.cfg.single_photref : aperture_index = 0'.
# Parsing: "x = srcproj.columns : srcproj_column_name = 'x' & srcproj_version = 0".
# Parsing: "y = srcproj.columns : srcproj_column_name = 'y' & srcproj_version = 0".
# Parsing: 'bg = bg.value'.
# Parsing: 'z = skypos.zenith_distance'.
# Parsing: "S = srcextract.psf_map.eval: srcextract_psf_param = 's'".
# 2025-07-03 10:44:38,888 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:38,891 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:38,891 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('light_curve', 0)
# 2025-07-03 10:44:38,898 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:38,898 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('light_curve', 0)
# 2025-07-03 10:44:38,900 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:38,900 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:38,903 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:38,903 INFO sqlalchemy.engine.Engine [generated in 0.00036s] ('light_curve', 0)
# 2025-07-03 10:44:38,906 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:38,989 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:38,992 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:38,993 INFO sqlalchemy.engine.Engine [generated in 0.00043s] ('light_curve', 0)
# 2025-07-03 10:44:39,000 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,000 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:39,003 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,004 INFO sqlalchemy.engine.Engine [generated in 0.00051s] ('light_curve', 0)
# 2025-07-03 10:44:39,007 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,009 INFO sqlalchemy.engine.Engine [generated in 0.00172s] ('light_curve', 0)
# 2025-07-03 10:44:39,011 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,061 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,065 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,065 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:39,069 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,070 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,071 INFO sqlalchemy.engine.Engine [generated in 0.00054s] ('light_curve', 0)
# 2025-07-03 10:44:39,072 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,072 INFO sqlalchemy.engine.Engine [generated in 0.00053s] ('light_curve', 0)
# 2025-07-03 10:44:39,074 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,074 INFO sqlalchemy.engine.Engine [generated in 0.00049s] ('light_curve', 0)
# 2025-07-03 10:44:39,080 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,080 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,080 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('light_curve', 0)
# 2025-07-03 10:44:39,081 INFO sqlalchemy.engine.Engine [generated in 0.00045s] ('light_curve', 0)
# 2025-07-03 10:44:39,083 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,083 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:39,084 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,086 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,086 INFO sqlalchemy.engine.Engine [generated in 0.00067s] ('light_curve', 0)
# 2025-07-03 10:44:39,091 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,176 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,179 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,180 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:39,186 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,186 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('light_curve', 0)
# 2025-07-03 10:44:39,188 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,188 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:39,191 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,191 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ('light_curve', 0)
# 2025-07-03 10:44:39,194 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,207 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,210 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,210 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('light_curve', 0)
# 2025-07-03 10:44:39,216 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,216 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ('light_curve', 0)
# 2025-07-03 10:44:39,219 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,219 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('light_curve', 0)
# 2025-07-03 10:44:39,222 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,222 INFO sqlalchemy.engine.Engine [generated in 0.00032s] ('light_curve', 0)
# 2025-07-03 10:44:39,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,224 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,227 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,227 INFO sqlalchemy.engine.Engine [generated in 0.00031s] ('light_curve', 0)
# 2025-07-03 10:44:39,238 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,238 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:39,240 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,240 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('light_curve', 0)
# 2025-07-03 10:44:39,243 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,244 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('light_curve', 0)
# 2025-07-03 10:44:39,246 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,249 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,253 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,253 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('light_curve', 0)
# 2025-07-03 10:44:39,258 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,259 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,259 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('light_curve', 0)
# 2025-07-03 10:44:39,260 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,261 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,261 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,262 INFO sqlalchemy.engine.Engine [generated in 0.00032s] ('light_curve', 0)
# 2025-07-03 10:44:39,261 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:39,263 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,263 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:39,265 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,265 INFO sqlalchemy.engine.Engine [generated in 0.00031s] ('light_curve', 0)
# 2025-07-03 10:44:39,268 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,270 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,270 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:39,272 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,272 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ('light_curve', 0)
# 2025-07-03 10:44:39,273 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,275 INFO sqlalchemy.engine.Engine [generated in 0.00203s] ('light_curve', 0)
# 2025-07-03 10:44:39,275 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attribu2025-07-03 10:44:39,278 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,278 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ('light_curve', 0)
# tes.hdf5_structure_version_id
# 2025-07-03 10:44:39,280 INFO sqlalchemy.engine.Engine [generated in 0.00499s] ('light_curve', 0)
# 2025-07-03 10:44:39,281 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,283 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,286 INFO sqlalchemy.engine.Engine [generated in 0.00274s] ('light_curve', 0)
# 2025-07-03 10:44:39,288 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,296 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,300 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,300 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('light_curve', 0)
# 2025-07-03 10:44:39,306 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,306 INFO sqlalchemy.engine.Engine [generated in 0.00062s] ('light_curve', 0)
# 2025-07-03 10:44:39,306 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:39,309 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:39,310 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,310 INFO sqlalchemy.engine.Engine [generated in 0.00059s] ('light_curve', 0)
# 2025-07-03 10:44:39,310 INFO sqlalchemy.engine.Engine [generated in 0.00084s] ('light_curve', 0)
# 2025-07-03 10:44:39,318 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,320 INFO sqlalchemy.engine.Engine [generated in 0.00141s] ('light_curve', 0)
# 2025-07-03 10:44:39,323 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:39,319 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:39,326 INFO sqlalchemy.engine.Engine [generated in 0.00701s] ('light_curve', 0)
# 2025-07-03 10:44:39,329 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:39,330 INFO sqlalchemy.engine.Engine [generated in 0.00103s] ('light_curve', 0)
# 2025-07-03 10:44:39,333 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:39,333 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('light_curve', 0)
# 2025-07-03 10:44:39,336 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Generate EPD statistics file for light curves

# %%
# !wisp-generate-epd-statistics --config test.cfg LC/
# Out:
# Parsing: 'sphotref = apphot.magfit.cfg.single_photref : aperture_index = 0'.
# 2025-07-03 10:44:43,338 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:43,340 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:43,340 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:44:43,343 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:43,344 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 0)
# 2025-07-03 10:44:43,345 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:43,345 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('data_reduction', 0)
# 2025-07-03 10:44:43,347 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:43,347 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:44:43,347 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:43,359 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:43,359 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:43,359 INFO sqlalchemy.engine.Engine [cached since 0.01946s ago] ('light_curve', 0)
# 2025-07-03 10:44:43,361 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:43,361 INFO sqlalchemy.engine.Engine [cached since 0.01739s ago] ('light_curve', 0)
# 2025-07-03 10:44:43,361 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:43,361 INFO sqlalchemy.engine.Engine [cached since 0.01637s ago] ('light_curve', 0)
# 2025-07-03 10:44:43,362 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:43,362 INFO sqlalchemy.engine.Engine [cached since 0.01474s ago] ('light_curve', 0)
# 2025-07-03 10:44:43,363 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:43,698 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:43,698 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:44:43,698 INFO sqlalchemy.engine.Engine [generated in 0.00010s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:43,701 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:43,701 INFO sqlalchemy.engine.Engine [generated in 0.00009s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:43,702 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:43,702 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:43,704 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:43,704 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:43,704 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Perform TFA on light curves

# %%
# !wisp-tfa --config test.cfg LC/
# Out:
# Parsing: 'sphotref = apphot.magfit.cfg.single_photref : aperture_index = 0'.
# 2025-07-03 10:44:47,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:47,225 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:47,225 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('data_reduction', 0)
# 2025-07-03 10:44:47,229 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:47,229 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 0)
# 2025-07-03 10:44:47,230 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:47,230 INFO sqlalchemy.engine.Engine [generated in 0.00015s] ('data_reduction', 0)
# 2025-07-03 10:44:47,232 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:47,232 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:44:47,233 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:47,245 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:47,246 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:44:47,246 INFO sqlalchemy.engine.Engine [generated in 0.00008s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:47,248 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:47,248 INFO sqlalchemy.engine.Engine [generated in 0.00008s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:47,249 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:47,249 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:47,250 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:47,251 INFO sqlalchemy.engine.Engine [generated in 0.00010s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:47,251 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:47,291 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:47,291 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:47,291 INFO sqlalchemy.engine.Engine [cached since 0.06636s ago] ('light_curve', 0)
# 2025-07-03 10:44:47,293 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:47,293 INFO sqlalchemy.engine.Engine [cached since 0.06428s ago] ('light_curve', 0)
# 2025-07-03 10:44:47,293 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:47,293 INFO sqlalchemy.engine.Engine [cached since 0.06327s ago] ('light_curve', 0)
# 2025-07-03 10:44:47,294 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:47,294 INFO sqlalchemy.engine.Engine [cached since 0.0617s ago] ('light_curve', 0)
# 2025-07-03 10:44:47,295 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:52,812 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:52,815 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:52,815 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:52,821 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:52,821 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('light_curve', 0)
# 2025-07-03 10:44:52,823 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:52,823 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('light_curve', 0)
# 2025-07-03 10:44:52,826 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:52,826 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('light_curve', 0)
# 2025-07-03 10:44:52,828 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:52,861 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:52,864 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:52,864 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:52,871 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:52,871 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('light_curve', 0)
# 2025-07-03 10:44:52,874 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:52,874 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('light_curve', 0)
# 2025-07-03 10:44:52,877 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:52,877 INFO sqlalchemy.engine.Engine [generated in 0.00021s] ('light_curve', 0)
# 2025-07-03 10:44:52,879 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:52,947 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:52,950 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:52,950 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:52,956 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:52,956 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('light_curve', 0)
# 2025-07-03 10:44:52,959 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:52,959 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ('light_curve', 0)
# 2025-07-03 10:44:52,962 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:52,964 INFO sqlalchemy.engine.Engine [generated in 0.00174s] ('light_curve', 0)
# 2025-07-03 10:44:52,968 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:53,004 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:53,007 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:53,007 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:53,016 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:53,016 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:53,016 INFO sqlalchemy.engine.Engine [generated in 0.00030s] ('light_curve', 0)
# 2025-07-03 10:44:53,017 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:53,019 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:53,020 INFO sqlalchemy.engine.Engine [generated in 0.00057s] ('light_curve', 0)
# 2025-07-03 10:44:53,020 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:53,020 INFO sqlalchemy.engine.Engine [generated in 0.00039s] ('light_curve', 0)
# 2025-07-03 10:44:53,021 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:53,023 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:53,023 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('light_curve', 0)
# 2025-07-03 10:44:53,024 INFO sqlalchemy.engine.Engine [generated in 0.00335s] ('light_curve', 0)
# 2025-07-03 10:44:53,026 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:53,030 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:53,030 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:53,032 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:53,033 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:53,033 INFO sqlalchemy.engine.Engine [generated in 0.00036s] ('light_curve', 0)
# 2025-07-03 10:44:53,033 INFO sqlalchemy.engine.Engine [generated in 0.00041s] ('light_curve', 0)
# 2025-07-03 10:44:53,036 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:53,036 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:53,037 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:53,041 INFO sqlalchemy.engine.Engine [generated in 0.00455s] ('light_curve', 0)
# 2025-07-03 10:44:53,043 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:53,043 INFO sqlalchemy.engine.Engine [generated in 0.00029s] ('light_curve', 0)
# 2025-07-03 10:44:53,044 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:53,046 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:53,050 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:53,052 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:53,053 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:53,053 INFO sqlalchemy.engine.Engine [generated in 0.00022s] ('light_curve', 0)
# 2025-07-03 10:44:53,057 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:53,057 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:53,059 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:53,059 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('light_curve', 0)
# 2025-07-03 10:44:53,061 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:53,061 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('light_curve', 0)
# 2025-07-03 10:44:53,063 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:53,064 INFO sqlalchemy.engine.Engine [generated in 0.00018s] ('light_curve', 0)
# 2025-07-03 10:44:53,064 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:53,065 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ('light_curve', 0)
# 2025-07-03 10:44:53,066 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# ...
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:53,090 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('light_curve', 0)
# 2025-07-03 10:44:53,093 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:53,093 INFO sqlalchemy.engine.Engine [generated in 0.00024s] ('light_curve', 0)
# 2025-07-03 10:44:53,096 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:53,112 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:53,115 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:53,115 INFO sqlalchemy.engine.Engine [generated in 0.00020s] ('light_curve', 0)
# 2025-07-03 10:44:53,118 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:53,121 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:53,121 INFO sqlalchemy.engine.Engine [generated in 0.00019s] ('light_curve', 0)
# 2025-07-03 10:44:53,121 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:53,122 INFO sqlalchemy.engine.Engine [generated in 0.00126s] ('light_curve', 0)
# 2025-07-03 10:44:53,127 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attribu2025-07-03 10:44:53,130 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:53,130 INFO sqlalchemy.engine.Engine [generated in 0.00023s] ('light_curve', 0)
# tes.hdf5_structure_version_id
# 2025-07-03 10:44:53,131 INFO sqlalchemy.engine.Engine [generated in 0.00422s] ('light_curve', 0)
# 2025-07-03 10:44:53,133 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:53,133 INFO sqlalchemy.engine.Engine [generated in 0.00027s] ('light_curve', 0)
# 2025-07-03 10:44:53,134 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:53,134 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('light_curve', 0)
# 2025-07-03 10:44:53,136 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:53,136 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:53,136 INFO sqlalchemy.engine.Engine [generated in 0.00034s] ('light_curve', 0)
# 2025-07-03 10:44:53,137 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:53,139 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:53,139 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:53,139 INFO sqlalchemy.engine.Engine [generated in 0.00046s] ('light_curve', 0)
# 2025-07-03 10:44:53,147 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:53,147 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ('light_curve', 0)
# 2025-07-03 10:44:53,150 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:53,150 INFO sqlalchemy.engine.Engine [generated in 0.00038s] ('light_curve', 0)
# 2025-07-03 10:44:53,153 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:53,154 INFO sqlalchemy.engine.Engine [generated in 0.00025s] ('light_curve', 0)
# 2025-07-03 10:44:53,156 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Generate TFA statistics file for light curves

# %%
# !wisp-generate-tfa-statistics --config test.cfg LC/
# Out:
# Parsing: 'sphotref = apphot.magfit.cfg.single_photref : aperture_index = 0'.
# 2025-07-03 10:44:58,991 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:58,993 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:58,993 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 0)
# 2025-07-03 10:44:58,997 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:58,997 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 0)
# 2025-07-03 10:44:58,998 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:58,998 INFO sqlalchemy.engine.Engine [generated in 0.00013s] ('data_reduction', 0)
# 2025-07-03 10:44:59,000 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:59,000 INFO sqlalchemy.engine.Engine [generated in 0.00014s] ('data_reduction', 0)
# 2025-07-03 10:44:59,001 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:59,013 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:59,013 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?
# 2025-07-03 10:44:59,013 INFO sqlalchemy.engine.Engine [cached since 0.01985s ago] ('light_curve', 0)
# 2025-07-03 10:44:59,014 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:59,015 INFO sqlalchemy.engine.Engine [cached since 0.01782s ago] ('light_curve', 0)
# 2025-07-03 10:44:59,015 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:59,015 INFO sqlalchemy.engine.Engine [cached since 0.01681s ago] ('light_curve', 0)
# 2025-07-03 10:44:59,015 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? AND hdf5_structure_versions.version = ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:59,015 INFO sqlalchemy.engine.Engine [cached since 0.01518s ago] ('light_curve', 0)
# 2025-07-03 10:44:59,017 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-03 10:44:59,346 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-03 10:44:59,347 INFO sqlalchemy.engine.Engine SELECT hdf5_structure_versions.hdf5_product_id AS hdf5_structure_versions_hdf5_product_id, hdf5_structure_versions.version AS hdf5_structure_versions_version, hdf5_structure_versions.id AS hdf5_structure_versions_id, hdf5_structure_versions.timestamp AS hdf5_structure_versions_timestamp, hdf5_products.pipeline_key AS hdf5_products_pipeline_key, hdf5_products.description AS hdf5_products_description, hdf5_products.id AS hdf5_products_id, hdf5_products.timestamp AS hdf5_products_timestamp
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?
# 2025-07-03 10:44:59,347 INFO sqlalchemy.engine.Engine [generated in 0.00010s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:59,349 INFO sqlalchemy.engine.Engine SELECT hdf5_links.hdf5_structure_version_id AS hdf5_links_hdf5_structure_version_id, hdf5_links.pipeline_key AS hdf5_links_pipeline_key, hdf5_links.abspath AS hdf5_links_abspath, hdf5_links.target AS hdf5_links_target, hdf5_links.description AS hdf5_links_description, hdf5_links.id AS hdf5_links_id, hdf5_links.timestamp AS hdf5_links_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_links ON hdf5_structure_versions_1.id = hdf5_links.hdf5_structure_version_id
# 2025-07-03 10:44:59,349 INFO sqlalchemy.engine.Engine [generated in 0.00009s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:59,350 INFO sqlalchemy.engine.Engine SELECT hdf5_attributes.hdf5_structure_version_id AS hdf5_attributes_hdf5_structure_version_id, hdf5_attributes.pipeline_key AS hdf5_attributes_pipeline_key, hdf5_attributes.parent AS hdf5_attributes_parent, hdf5_attributes.name AS hdf5_attributes_name, hdf5_attributes.dtype AS hdf5_attributes_dtype, hdf5_attributes.description AS hdf5_attributes_description, hdf5_attributes.id AS hdf5_attributes_id, hdf5_attributes.timestamp AS hdf5_attributes_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_attributes ON hdf5_structure_versions_1.id = hdf5_attributes.hdf5_structure_version_id
# 2025-07-03 10:44:59,351 INFO sqlalchemy.engine.Engine [generated in 0.00012s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:59,352 INFO sqlalchemy.engine.Engine SELECT hdf5_datasets.hdf5_structure_version_id AS hdf5_datasets_hdf5_structure_version_id, hdf5_datasets.pipeline_key AS hdf5_datasets_pipeline_key, hdf5_datasets.abspath AS hdf5_datasets_abspath, hdf5_datasets.dtype AS hdf5_datasets_dtype, hdf5_datasets.compression AS hdf5_datasets_compression, hdf5_datasets.compression_options AS hdf5_datasets_compression_options, hdf5_datasets.scaleoffset AS hdf5_datasets_scaleoffset, hdf5_datasets.shuffle AS hdf5_datasets_shuffle, hdf5_datasets.replace_nonfinite AS hdf5_datasets_replace_nonfinite, hdf5_datasets.description AS hdf5_datasets_description, hdf5_datasets.id AS hdf5_datasets_id, hdf5_datasets.timestamp AS hdf5_datasets_timestamp, hdf5_structure_versions_1.id AS hdf5_structure_versions_1_id
# FROM (SELECT hdf5_products.id AS hdf5_products_id
# FROM hdf5_products JOIN hdf5_structure_versions ON hdf5_products.id = hdf5_structure_versions.hdf5_product_id
# WHERE hdf5_products.pipeline_key = ? ORDER BY hdf5_structure_versions.version DESC
#  LIMIT ? OFFSET ?) AS anon_1 JOIN hdf5_structure_versions AS hdf5_structure_versions_1 ON anon_1.hdf5_products_id = hdf5_structure_versions_1.hdf5_product_id JOIN hdf5_datasets ON hdf5_structure_versions_1.id = hdf5_datasets.hdf5_structure_version_id
# 2025-07-03 10:44:59,352 INFO sqlalchemy.engine.Engine [generated in 0.00011s] ('data_reduction', 1, 0)
# 2025-07-03 10:44:59,353 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# When you are done reviewing your results, remember to delete the directory you created at the beginning
